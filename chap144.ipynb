# %% [markdown]
# #### Smoothing Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img=cv2.imread('cutedog.png')
kernel=np.ones((5,5),np.float32)/25
dst=cv2.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# #### Averaging

# %%
img=cv2.imread('cutedog.png')
blur1 = cv2.blur(img,(3,3))
blur2 = cv2.blur(img,(5,5))
plt.subplot(121),plt.imshow(blur1),plt.title('blur1')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur2),plt.title('blur2')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Gaussian Filtering

# %%
img=cv2.imread('cutedog.png')
#blur1 = cv2.blur(img,(3,3))
blur2 = cv2.blur(img,(5,5)) #평균값
#blur1 = cv2.GaussianBlur(img,(3,3))
GaussianBlur2 = cv2.GaussianBlur(img,(5,5),0)#?
medianBlur2 = cv2.medianBlur(img,15) #3by3 커널로 3by3안에 애들을 sorting해서 5번째 순위 값을 가져옴
bilateralBlur2 = cv2.bilateralFilter(img,9,75,75)#?
plt.subplot(121),plt.imshow(blur1),plt.title('blur1')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(GaussianBlur2),plt.title('Gaussianblur2')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(medianBlur2),plt.title('medianBlur2')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(bilateralBlur2),plt.title('bilateralBlur2')
plt.xticks([]), plt.yticks([])
plt.show()
